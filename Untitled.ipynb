# %%
from pathlib import Path
from atlaselectrophysiology.extract_files import extract_data

# Path to KS2 output
ks_path = Path(r"D:\3556-17\3556-17_naive_g0\sorted\sorter_output")

# Path to raw ephys data
ephys_path = Path(r"D:\3556-17\3556-17_naive_g0\3556-17_naive_g0_imec0")

# Save path
out_path = Path(r"D:\3556-17\histology\tiffs\slices\iblnaive")

extract_data(ks_path, ephys_path, out_path)
# Out:
# C:\Users\Freitag\AppData\Local\anaconda3\envs\hist\lib\site-packages\phylib\io\model.py:1090: RuntimeWarning: invalid value encountered in divide
#   spikes_depths[ispi] = (np.sum(np.transpose(ypos * features) /
# Converting to ALF:  41%|████      | 55/135 [00:17<00:27,  2.89it/s]
# Extracting waveforms:   0%|          | 0/4678.846029486765 [00:00<?, ?it/s]
# Extracting waveforms:  26%|██▌       | 1200.0/4678.846029486765 [00:40<01:57, 29.64it/s]
# Extracting waveforms:  38%|███▊      | 1800.0/4678.846029486765 [00:57<01:31, 31.40it/s]
# Extracting waveforms:  51%|█████▏    | 2400.0/4678.846029486765 [01:04<00:54, 42.12it/s]
# Extracting waveforms:  51%|█████▏    | 2400.0/4678.846029486765 [01:18<00:54, 42.12it/s]
# Extracting waveforms:  64%|██████▍   | 3000.0/4678.846029486765 [01:33<00:55, 30.47it/s]
# Extracting waveforms:  64%|██████▍   | 3000.0/4678.846029486765 [01:48<00:55, 30.47it/s]
# Extracting waveforms:  77%|███████▋  | 3600.0/4678.846029486765 [02:04<00:41, 25.83it/s]
# Extracting waveforms:  77%|███████▋  | 3600.0/4678.846029486765 [02:18<00:41, 25.83it/s]
# Extracting waveforms:  90%|████████▉ | 4200.0/4678.846029486765 [02:38<00:21, 22.30it/s]
# Extracting waveforms:  90%|████████▉ | 4200.0/4678.846029486765 [02:58<00:21, 22.30it/s]
# Extracting waveforms: 100%|██████████| 4678.846029486765/4678.846029486765 [03:15<00:00, 18.86it/s]
# Extracting waveforms: 100%|██████████| 4678.846029486765/4678.846029486765 [03:44<00:00, 20.83it/s]
# Converting to ALF: 155it [04:16,  1.66s/it]
# 2025-08-20 17:08:56 INFO     extract_files.py:82   Computing QC for D:\3556-17\3556-17_naive_g0\3556-17_naive_g0_imec0\3556-17_naive_g0_t0.imec0.ap.bin
# 40964it [1:16:33,  8.92it/s]
# 2025-08-20 18:25:33 INFO     extract_files.py:82   Computing QC for D:\3556-17\3556-17_naive_g0\3556-17_naive_g0_imec0\3556-17_naive_g0_t0.imec0.lf.bin
# 52725it [07:42, 114.10it/s]

# %%
12
# Out:
# 12

# %%
import numpy as np
from pathlib import Path
import json
from iblatlas import atlas

res=10
atlas = atlas.AllenAtlas(res)

brainreg_path = Path(r"D:\3556-17\histology\tiffs\slices\probecoord.npy")
# Load in coordinates of track in CCF space (order - apdvml, origin - top, left, front voxel
xyz_apdvml = np.load(brainreg_path)
xyz_apdvml = xyz_apdvml*res
# Convert to IBL space (order - mlapdv, origin - bregma)
xyz_mlapdv = atlas.ccf2xyz(xyz_apdvml, ccf_order='apdvml') * 1e6
xyz_picks = {'xyz_picks': xyz_mlapdv.tolist()}

# Path to save the data (same folder as where you have all the data)
output_path = Path(r"D:\3556-17\histology\tiffs\slices\ibl")
with open(Path(output_path, 'xyz_picks.json'), "w") as f:
    json.dump(xyz_picks, f, indent=2)

print('done')
# Out:
# done
