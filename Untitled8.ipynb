# %%
import spikeinterface.full as si
import matplotlib.pyplot as plt
import numpy as np
import probeinterface as pi
from pathlib import Path
import pandas as pd 
import os, sys
import shutil
from pprint import pprint 
import time as time


    
global_job_kwargs = dict(n_jobs=-3, chunk_duration="10s",progress_bar=True)
si.set_global_job_kwargs(**global_job_kwargs)


basefolder= r"I:\Data\raw\8186\8186_naive"
base_path = Path(basefolder)
metapath = base_path / 'Meta'
if not os.path.isdir(metapath):
   os.makedirs(metapath)



recording =  si.read_spikeglx(basefolder, stream_id='imec0.ap', load_sync_channel=False)
lfp = si.read_spikeglx(basefolder, stream_id='imec0.lf', load_sync_channel=False)
event =  si.read_spikeglx(basefolder, stream_id='nidq', load_sync_channel=False)
print(recording)
# Out:
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 143,519,397 samples
#                             4,784.00s (1.33 hours) - int16 dtype - 102.65 GiB

# %%
#recording = si.ChannelSliceRecording(recording, channel_ids=recording.get_channel_ids()[180:330])

sampling_frequency = recording.sampling_frequency
rec1 = recording_slice_frames = recording.frame_slice(start_frame=0,
                                               end_frame=int(3860*sampling_frequency))

#rec1 = si.highpass_filter(recording, freq_min=400.)
rec1 = si.bandpass_filter(recording)
rec1 = si.phase_shift(rec1)
bad_channel_ids, channel_labels = si.detect_bad_channels(rec1,method = 'coherence+psd')
print(bad_channel_ids)
rec1 = si.interpolate_bad_channels(recording=rec1, bad_channel_ids=bad_channel_ids)

rec1 = si.common_reference(rec1, operator="median", reference="global")
print(rec1)


# %matplotlib widget
si.plot_traces({'raw':recording,'filtered':rec1}, backend='ipywidgets')

from spikeinterface.sorters import installed_sorters
installed_sorters()
import torch
print(torch.cuda.is_available())
print(torch.cuda.current_device())
torch.cuda.get_device_name(0)
# Out:
# ['imec0.ap#AP191']
# CommonReferenceRecording: 384 channels - 29999.900000 Hz - 1 segments - 143,519,397 samples
#                           4,784.00s (1.33 hours) - int16 dtype - 102.65 GiB
# AppLayout(children=(TimeSlider(children=(Dropdown(description='Segment', options=(0,), value=0), Button(icon='…
# True
# 0
# 'NVIDIA RTX A4000'

# %%
Sorting_KS4 = si.run_sorter(sorter_name="kilosort4", recording=rec1, folder=basefolder + str('/sorted'),remove_existing_folder=True)
analyzer = si.create_sorting_analyzer(Sorting_KS4, rec1, sparse=True, format='binary_folder',folder=basefolder +str('/analyzer'))

analyzer.compute(['random_spikes', 'waveforms', 'templates', 'noise_levels','unit_locations','correlograms'],**global_job_kwargs)
analyzer.compute('spike_amplitudes')
analyzer.compute('principal_components', n_components = 5, mode="by_channel_local",**global_job_kwargs)
analyzer.compute(["spike_locations", "template_metrics", "quality_metrics"],**global_job_kwargs)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2392/2392 [28:50<00:00,  1.38it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2392/2392 [26:53<00:00,  1.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:33<00:00, 153.88s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2392/2392 [10:24<00:00,  3.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:50<00:00, 170.63s/it]
# estimate_sparsity (workers: 38 processes spawn):   0%|          | 0/479 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 38 processes spawn):   0%|          | 0/479 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 38 processes spawn):   0%|          | 0/479 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/528 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/528 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 analyzer.compute('spike_amplitudes')
#       6 analyzer.compute('principal_components', n_components = 5, mode="by_channel_local",**global_job_kwargs)
# ----> 7 analyzer.compute(["spike_locations", "template_metrics", "quality_metrics"]**global_job_kwargs)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'dict'

# %%
analyzer.compute(["spike_locations", "template_metrics", "quality_metrics"],**global_job_kwargs)
# Out:
# Compute : spike_locations (workers: 38 processes spawn):   0%|          | 0/479 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\_methods.py:219: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\_methods.py:178: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\_methods.py:211: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\metrics\quality\misc_metrics.py:1026: UserWarning: Amplitude cutoff set to NaN for units [np.int64(3), np.int64(6), np.int64(7), np.int64(10), np.int64(11), np.int64(15), np.int64(16), np.int64(18), np.int64(19), np.int64(25), np.int64(26), np.int64(27), np.int64(29), np.int64(30), np.int64(31), np.int64(35), np.int64(36), np.int64(37), np.int64(41), np.int64(42), np.int64(45), np.int64(46), np.int64(48), np.int64(49), np.int64(51), np.int64(58), np.int64(65), np.int64(71), np.int64(72), np.int64(75), np.int64(78), np.int64(81), np.int64(85), np.int64(90), np.int64(92), np.int64(100), np.int64(101), np.int64(109), np.int64(113), np.int64(117), np.int64(121), np.int64(123), np.int64(128), np.int64(130), np.int64(131), np.int64(132), np.int64(135), np.int64(137), np.int64(144), np.int64(146), np.int64(147), np.int64(154), np.int64(155), np.int64(158), np.int64(160), np.int64(163), np.int64(169), np.int64(176), np.int64(177), np.int64(178), np.int64(184), np.int64(186), np.int64(191), np.int64(192), np.int64(193), np.int64(195), np.int64(196), np.int64(197), np.int64(198), np.int64(199), np.int64(204), np.int64(205), np.int64(220), np.int64(221), np.int64(228), np.int64(236), np.int64(241), np.int64(253), np.int64(254), np.int64(255), np.int64(262), np.int64(264), np.int64(268), np.int64(272), np.int64(282), np.int64(283), np.int64(291), np.int64(303), np.int64(304), np.int64(316), np.int64(320), np.int64(323), np.int64(335), np.int64(355), np.int64(358), np.int64(362), np.int64(369), np.int64(371), np.int64(384), np.int64(393), np.int64(398), np.int64(402), np.int64(409), np.int64(415), np.int64(420), np.int64(425), np.int64(428), np.int64(441), np.int64(442), np.int64(443), np.int64(452), np.int64(461), np.int64(463), np.int64(464), np.int64(471), np.int64(477), np.int64(479), np.int64(489), np.int64(491), np.int64(495), np.int64(498), np.int64(500), np.int64(503), np.int64(504), np.int64(508), np.int64(510), np.int64(512), np.int64(513), np.int64(514), np.int64(516), np.int64(521), np.int64(522), np.int64(524)]: too few spikes (< 500).
#   warnings.warn(
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\metrics\quality\misc_metrics.py:1323: UserWarning: Drift metrics could not be computed for units [np.int64(2), np.int64(3), np.int64(6), np.int64(7), np.int64(8), np.int64(10), np.int64(11), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(40), np.int64(41), np.int64(42), np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49), np.int64(51), np.int64(52), np.int64(53), np.int64(54), np.int64(55), np.int64(58), np.int64(60), np.int64(63), np.int64(64), np.int64(65), np.int64(67), np.int64(69), np.int64(71), np.int64(72), np.int64(74), np.int64(75), np.int64(76), np.int64(77), np.int64(78), np.int64(81), np.int64(82), np.int64(83), np.int64(85), np.int64(89), np.int64(90), np.int64(91), np.int64(92), np.int64(96), np.int64(99), np.int64(100), np.int64(101), np.int64(103), np.int64(105), np.int64(106), np.int64(107), np.int64(109), np.int64(110), np.int64(111), np.int64(113), np.int64(114), np.int64(115), np.int64(116), np.int64(117), np.int64(121), np.int64(123), np.int64(124), np.int64(125), np.int64(126), np.int64(128), np.int64(129), np.int64(130), np.int64(131), np.int64(132), np.int64(134), np.int64(135), np.int64(137), np.int64(139), np.int64(140), np.int64(141), np.int64(144), np.int64(146), np.int64(147), np.int64(148), np.int64(149), np.int64(150), np.int64(152), np.int64(153), np.int64(154), np.int64(155), np.int64(156), np.int64(158), np.int64(159), np.int64(160), np.int64(161), np.int64(162), np.int64(163), np.int64(164), np.int64(166), np.int64(167), np.int64(169), np.int64(170), np.int64(173), np.int64(175), np.int64(176), np.int64(177), np.int64(178), np.int64(179), np.int64(184), np.int64(185), np.int64(186), np.int64(187), np.int64(189), np.int64(190), np.int64(191), np.int64(192), np.int64(193), np.int64(195), np.int64(196), np.int64(197), np.int64(198), np.int64(199), np.int64(200), np.int64(201), np.int64(204), np.int64(205), np.int64(206), np.int64(207), np.int64(208), np.int64(209), np.int64(210), np.int64(214), np.int64(218), np.int64(219), np.int64(220), np.int64(221), np.int64(222), np.int64(226), np.int64(227), np.int64(228), np.int64(231), np.int64(234), np.int64(235), np.int64(236), np.int64(239), np.int64(240), np.int64(241), np.int64(242), np.int64(243), np.int64(245), np.int64(246), np.int64(247), np.int64(249), np.int64(250), np.int64(251), np.int64(253), np.int64(254), np.int64(255), np.int64(256), np.int64(259), np.int64(261), np.int64(262), np.int64(264), np.int64(266), np.int64(267), np.int64(268), np.int64(269), np.int64(272), np.int64(273), np.int64(274), np.int64(275), np.int64(276), np.int64(278), np.int64(281), np.int64(282), np.int64(283), np.int64(287), np.int64(289), np.int64(290), np.int64(291), np.int64(293), np.int64(299), np.int64(301), np.int64(302), np.int64(303), np.int64(304), np.int64(307), np.int64(309), np.int64(312), np.int64(314), np.int64(315), np.int64(316), np.int64(319), np.int64(320), np.int64(322), np.int64(323), np.int64(324), np.int64(328), np.int64(332), np.int64(334), np.int64(335), np.int64(336), np.int64(338), np.int64(340), np.int64(342), np.int64(348), np.int64(349), np.int64(350), np.int64(352), np.int64(353), np.int64(354), np.int64(355), np.int64(356), np.int64(357), np.int64(358), np.int64(359), np.int64(360), np.int64(362), np.int64(364), np.int64(366), np.int64(369), np.int64(370), np.int64(371), np.int64(373), np.int64(374), np.int64(375), np.int64(379), np.int64(381), np.int64(384), np.int64(385), np.int64(386), np.int64(387), np.int64(388), np.int64(389), np.int64(393), np.int64(394), np.int64(398), np.int64(400), np.int64(402), np.int64(403), np.int64(404), np.int64(405), np.i ...
#   warnings.warn(
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\metrics\quality\pca_metrics.py:370: RuntimeWarning: Degrees of freedom <= 0 for slice
#   VI = np.linalg.inv(np.cov(pcs_for_this_unit.T))
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\lib\_function_base_impl.py:2888: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Freitag\si_env\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plot_path =base_path/'plots'
spike_times_path = base_path / 'spike_times'


# Load Data

sf = recording.sampling_frequency

# 1. Bombcell & Labels
bc_results = si.bombcell_label_units(analyzer, thresholds=si.bombcell_get_default_thresholds())
labels = bc_results["bombcell_label"].values
analyzer.sorting.set_property("bombcell_label", labels)

# Save Labels Plot
w = si.plot_unit_labels(analyzer, labels, ylims=(-300, 100))
w.figure.savefig(plot_path / "bombcell_labels.png")
plt.close(w.figure)



spikes = pd.DataFrame(analyzer.sorting.to_spike_vector())
label_map = pd.Series(labels, index=range(len(analyzer.unit_ids)))
spikes['label'] = spikes['unit_index'].map(label_map)
spikes['time_s'] = spikes['sample_index'] / analyzer.sampling_frequency
spike_df = spikes.drop(columns=['segment_index'], errors='ignore')
spike_df.to_csv(spike_times_path / 'spike_times.csv', index=False)


# Convert to records and save
structured_array = spike_df.to_records(index=False)


np.save(spike_times_path / 'spike_times.npy', structured_array)

# %%
from scipy.signal import medfilt
from scipy.interpolate import interp1d


def ttl_from_analog(signal, fs, hysteresis=0.1, filt_kernel=5):
    signal_f = medfilt(signal, kernel_size=filt_kernel)
    v_low = np.percentile(signal_f, 5)
    v_high = np.percentile(signal_f, 95)
    v_lo = v_low + hysteresis * (v_high - v_low)
    v_hi = v_high - hysteresis * (v_high - v_low)

    digital = np.zeros_like(signal_f, dtype=np.int8)
    state = 0
    for i, v in enumerate(signal_f):
        if state == 0 and v > v_hi: state = 1
        elif state == 1 and v < v_lo: state = 0
        digital[i] = state
    d = np.diff(digital)
    rising_idx = np.where(d == 1)[0] + 1
    falling_idx = np.where(d == -1)[0] + 1
    return digital, rising_idx, falling_idx

def quadrature_speed_direction(sigA, sigB, fs, pulses_per_rev=360, hysteresis=0.1):
    sig_len = len(sigA)
    time_full = np.arange(sig_len) / fs
    digA, rising_A, _ = ttl_from_analog(sigA, fs, hysteresis)
    digB, _, _ = ttl_from_analog(sigB, fs, hysteresis)
    if len(rising_A) < 2:
        return time_full * 1000, np.zeros(sig_len), np.zeros(sig_len)
    t_edges = rising_A / fs
    direction_edges = np.where(digB[rising_A] == 0, 1, -1)
    deg_per_edge = 360.0 / pulses_per_rev
    dtheta = direction_edges * deg_per_edge
    dt = np.diff(t_edges)
    speed_edges = np.diff(np.cumsum(dtheta)) / dt
    dir_edges = direction_edges[1:]
    t_mid = (t_edges[1:] + t_edges[:-1]) / 2
    f_speed = interp1d(t_mid, speed_edges, kind='previous', bounds_error=False, fill_value=0)
    f_dir = interp1d(t_mid, dir_edges, kind='previous', bounds_error=False, fill_value=0)
    return time_full * 1000, f_speed(time_full), f_dir(time_full)

def extract_ttl_from_bit(digital_word, bit, sampling_rate, plot_path, savename, plot=True):
    ttl_signal = (digital_word >> bit) & 1
    time_axis = np.arange(len(ttl_signal)) / sampling_rate
    if plot:
        plt.figure(figsize=(15, 3))
        plt.plot(time_axis, ttl_signal)
        plt.title(f'Isolated Bit {bit} ({savename})')
        plt.savefig(plot_path / f"ttl_bit_{bit}_{savename}.png")
        plt.close()
    diff = np.diff(ttl_signal)
    rising_idx = np.where(diff > 0)[0]
    falling_idx = np.where(diff < 0)[0]
    edges = np.concatenate([rising_idx / sampling_rate, falling_idx / sampling_rate])
    types = (['rising'] * len(rising_idx)) + (['falling'] * len(falling_idx))
    return pd.DataFrame({'timestamps': edges, 'edge_type': types}).sort_values('timestamps').reset_index(drop=True)

def extract_and_save_ttl_events(data, bit_name_pairs, save_path, plot_path):
    # CRITICAL: return_scaled=False so bitwise >> works on integers
    digital_signals = data.get_traces(return_in_uV=False)
    digital_word = digital_signals[:, 8]
    sampling_rate = data.get_sampling_frequency()
    for bit, savename in bit_name_pairs:
        ttl_df = extract_ttl_from_bit(digital_word, bit, sampling_rate, plot_path, savename)
        ttl_df.to_csv(save_path / f"{savename}.csv", index=False)
        
 # 4. Camera & Audio/State TTLs
cam_signal = event.get_traces(channel_ids=[event.get_channel_ids()[3]]).squeeze()
_, _, falling_A = ttl_from_analog(cam_signal, sf)
if len(falling_A) > 0:
    pd.DataFrame({'camttl': [falling_A[0] / sf]}).to_csv(metapath / 'camttl.csv', index=False)

pairs = [(1, 'State_changes'), (3, 'Audio')]
extract_and_save_ttl_events(event, pairs, metapath, plot_path)
# Out:
# C:\Users\Freitag\AppData\Local\Temp\ipykernel_33292\1187863774.py:60: DeprecationWarning: `return_scaled` is deprecated and will be removed in version 0.105.0. Use `return_in_uV` instead.
#   digital_signals = data.get_traces(return_scaled=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

x_sec = 800

# --- extract Audio TTL directly ---
bit = 3  # Audio
digital_signals = event.get_traces(return_in_uV=False)
digital_word = digital_signals[:, 8]
sampling_rate = event.get_sampling_frequency()

ttl_signal = (digital_word >> bit) & 1
time = np.arange(len(ttl_signal)) / sampling_rate

 # change this to whatever you want

n_samples = int(x_sec * sampling_rate)

ttl_signal = ttl_signal[:n_samples]
time = time[:n_samples]

# also trim edges so they match

# edges
diff = np.diff(ttl_signal)
rising_idx = np.where(diff > 0)[0]
falling_idx = np.where(diff < 0)[0]

rising_idx = rising_idx[rising_idx < n_samples]
falling_idx = falling_idx[falling_idx < n_samples]

# --- plot ---
plt.figure(figsize=(15, 4))

plt.plot(time, ttl_signal, label='Audio TTL')

plt.scatter(rising_idx / sampling_rate,
            np.ones_like(rising_idx),
            marker='^',
            label='rising')

plt.scatter(falling_idx / sampling_rate,
            np.zeros_like(falling_idx),
            marker='v',
            label='falling')

plt.ylim(-0.2, 1.2)
plt.title("Audio TTL (bit 3)")
plt.xlabel("Time (s)")
plt.legend()

plt.tight_layout()
plt.show()


bit = 1  # Audio
digital_signals = event.get_traces(return_in_uV=False)
digital_word = digital_signals[:, 8]
sampling_rate = event.get_sampling_frequency()

ttl_signal = (digital_word >> bit) & 1
time = np.arange(len(ttl_signal)) / sampling_rate

#change this to whatever you want

n_samples = int(x_sec * sampling_rate)

ttl_signal = ttl_signal[:n_samples]
time = time[:n_samples]

# also trim edges so they match

# edges
diff = np.diff(ttl_signal)
rising_idx = np.where(diff > 0)[0]
falling_idx = np.where(diff < 0)[0]

rising_idx = rising_idx[rising_idx < n_samples]
falling_idx = falling_idx[falling_idx < n_samples]

# --- plot ---
plt.figure(figsize=(15, 4))

plt.plot(time, ttl_signal, label='Audio TTL')

plt.scatter(rising_idx / sampling_rate,
            np.ones_like(rising_idx),
            marker='^',
            label='rising')

plt.scatter(falling_idx / sampling_rate,
            np.zeros_like(falling_idx),
            marker='v',
            label='falling')

plt.ylim(-0.2, 1.2)
plt.title("Audio TTL (bit 3)")
plt.xlabel("Time (s)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
