# %%
from pathlib import Path
from atlaselectrophysiology.extract_files import extract_data

# Path to KS2 output
ks_path = Path(r"D:\Data\3198-52\3198-52_g0\sorted\sorter_output")

# Path to raw ephys data
ephys_path = Path(r"D:\Data\3198-52\3198-52_g0\3198-52_g0_imec0")

# Save path
out_path = Path(r"D:\Data\3198-52\3198-52_g0\ibl_naive2")

extract_data(ks_path, ephys_path, out_path)
# Out:
# C:\Users\Freitag\AppData\Local\anaconda3\envs\hist\lib\site-packages\phylib\io\model.py:1090: RuntimeWarning: invalid value encountered in divide
#   spikes_depths[ispi] = (np.sum(np.transpose(ypos * features) /
# Converting to ALF:  41%|████      | 55/135 [00:08<00:14,  5.62it/s]
# Converting to ALF:  41%|████      | 55/135 [00:20<00:14,  5.62it/s], ?it/s]
# Extracting waveforms:  26%|██▋       | 1200.0/4562.996776655922 [00:10<00:30, 109.61it/s]
# Extracting waveforms:  39%|███▉      | 1800.0/4562.996776655922 [00:26<00:44, 62.42it/s]
# Extracting waveforms:  39%|███▉      | 1800.0/4562.996776655922 [00:39<00:44, 62.42it/s]
# Extracting waveforms:  53%|█████▎    | 2400.0/4562.996776655922 [00:43<00:45, 47.73it/s]
# Extracting waveforms:  66%|██████▌   | 3000.0/4562.996776655922 [00:56<00:33, 47.11it/s]
# Extracting waveforms:  66%|██████▌   | 3000.0/4562.996776655922 [01:09<00:33, 47.11it/s]
# Extracting waveforms:  79%|███████▉  | 3600.0/4562.996776655922 [01:10<00:20, 46.02it/s]
# Extracting waveforms:  92%|█████████▏| 4200.0/4562.996776655922 [01:26<00:08, 42.95it/s]
# Extracting waveforms:  92%|█████████▏| 4200.0/4562.996776655922 [01:39<00:08, 42.95it/s]
# Extracting waveforms: 100%|██████████| 4562.996776655922/4562.996776655922 [01:59<00:00, 38.33it/s]
# Converting to ALF: 155it [02:24,  1.07it/s]
# 2025-10-08 18:21:32 INFO     extract_files.py:82   Computing QC for D:\Data\3198-52\3198-52_g0\3198-52_g0_imec0\3198-52_g0_t0.imec0.ap.bin
# 42120it [1:08:11, 10.29it/s]
# 2025-10-08 19:29:48 INFO     extract_files.py:82   Computing QC for D:\Data\3198-52\3198-52_g0\3198-52_g0_imec0\3198-52_g0_t0.imec0.lf.bin
# 54054it [06:55, 129.94it/s]

# %%
import numpy as np
from pathlib import Path
import json
from iblatlas import atlas

res=10
atlas = atlas.AllenAtlas(res)

brainreg_path = Path(r"D:\51\52\results\probes.npy.mldatx_probe1.npy")
# Load in coordinates of track in CCF space (order - apdvml, origin - top, left, front voxel
xyz_apdvml = np.load(brainreg_path)
xyz_apdvml = xyz_apdvml*res
# Convert to IBL space (order - mlapdv, origin - bregma)
xyz_mlapdv = atlas.ccf2xyz(xyz_apdvml, ccf_order='apdvml') * 1e6
xyz_picks = {'xyz_picks': xyz_mlapdv.tolist()}

# Path to save the data (same folder as where you have all the data)
output_path = Path(r"D:\Data\3198-52\3198-52_g0\ibl_naive2")
with open(Path(output_path, 'xyz_picks.json'), "w") as f:
    json.dump(xyz_picks, f, indent=2)

print('done')
# Out:
# done
