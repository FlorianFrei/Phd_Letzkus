# %%
import os

def find_folders_without_sorted(root_dir):
    result = []

    # iterate over all directories at the top level
    for entry in os.scandir(root_dir):
        if entry.is_dir():
            has_sorted = False

            # walk through all subfolders of this top-level folder
            for dirpath, dirnames, filenames in os.walk(entry.path):
                if "sorted" in dirnames:
                    has_sorted = True
                    break  # no need to continue searching

            if not has_sorted:
                result.append(entry.path)

    return result


# Example usage
root = r"H:\Data\raw"
folders = find_folders_without_sorted(root)

for f in folders:
    print(f)
# Out:
# H:\Data\raw\8251_recall_g0
# H:\Data\raw\8182_naive_g2
# H:\Data\raw\8181_naivel_g0
# H:\Data\raw\8252_recall_g0
# H:\Data\raw\8252_naive_g0
# H:\Data\raw\8251_naive_g0
# H:\Data\raw\8273_recall_g0
# H:\Data\raw\8272_recall_g0
# H:\Data\raw\8273_naive_g0
# H:\Data\raw\8272_g1
# H:\Data\raw\8181_recall_g0
# H:\Data\raw\8182_recall_g0

# %%
import spikeinterface.full as si
import torch
import gc
from pathlib import Path
import shutil
import pandas as pd
import time

def run_kilosort_pipeline(basefolders, n_jobs=-2):
    """
    Run Kilosort4 and analysis pipeline for each basefolder in basefolders.

    Parameters
    ----------
    basefolders : list[str or Path]
        List of folders containing raw SpikeGLX data.
    n_jobs : int
        Number of jobs for parallel processing (default: -3)
    """
    global_job_kwargs = dict(n_jobs=n_jobs, chunk_duration="5s", progress_bar=True)
    si.set_global_job_kwargs(**global_job_kwargs)

    for basefolder in basefolders:
        basefolder = Path(basefolder)
        metapath = basefolder / 'Meta'
        metapath.mkdir(exist_ok=True, parents=True)

        print(f"\n=== Processing {basefolder} ===")

        try:
            # --- Load data
            recording = si.read_spikeglx(basefolder, stream_id='imec0.ap', load_sync_channel=False)
            lfp = si.read_spikeglx(basefolder, stream_id='imec0.lf', load_sync_channel=False)
            event = si.read_spikeglx(basefolder, stream_id='nidq', load_sync_channel=False)
            print(recording)

            # --- Preprocessing
            rec1 = si.bandpass_filter(recording)
            rec1 = si.phase_shift(rec1)
            bad_channel_ids, channel_labels = si.detect_bad_channels(rec1, method='coherence+psd')
            print(f"Bad channels: {bad_channel_ids}")
            rec1 = si.interpolate_bad_channels(rec1, bad_channel_ids=bad_channel_ids)
            rec1 = si.common_reference(rec1, operator="median", reference="global")

            # --- Sorting
            sorted_folder = basefolder / 'sorted'
            Sorting_KS4 = si.run_sorter(sorter_name="kilosort4", recording=rec1, folder=sorted_folder ,remove_existing_folder=True)
            #Sorting_KS4 = si.read_kilosort(sorted_folder / 'sorter_output')
            # --- Analyzer setup
            analyzer_folder = basefolder / 'analyzer'
            analyzer = si.create_sorting_analyzer(Sorting_KS4, rec1, sparse=True, format='binary_folder',folder= analyzer_folder)

            analyzer.compute(['random_spikes', 'waveforms', 'templates', 'noise_levels',
                              'unit_locations', 'correlograms'], **global_job_kwargs)
            analyzer.compute('spike_amplitudes')
            analyzer.compute('principal_components', n_components=5,
                             mode="by_channel_local", **global_job_kwargs)

            # --- Metrics
            
            print(analyzer)

            # --- Export to Phy
            phy_folder = basefolder / 'sorted' / 'phy'
            si.export_to_phy(analyzer, output_folder=phy_folder, **global_job_kwargs)

            print(f"✅ Finished {basefolder}")
        
        except Exception as e:
            print(f"❌ Error processing {basefolder}: {e}")
        
        finally:
            # --- Memory cleanup
            del recording, lfp, event, rec1
            if 'Sorting_KS4' in locals(): del Sorting_KS4
            if 'analyzer' in locals(): del analyzer
            if 'analyzer_clean' in locals(): del analyzer_clean
            gc.collect()

            
            torch.cuda.empty_cache()
            time.sleep(3)
            print(f"🧹 Memory cleared for {basefolder}")

os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Force Kilosort to use GPU 0

# Example usage
basefolders = folders
run_kilosort_pipeline(basefolders)
# Out:
# === Processing H:\Data\raw\8251_recall_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 146,941,580 samples
#                             4,898.07s (1.36 hours) - int16 dtype - 105.10 GiB
# Bad channels: ['imec0.ap#AP191']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2450/2450 [30:54<00:00,  1.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2450/2450 [30:53<00:00,  1.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [07:17<00:00, 437.03s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2450/2450 [37:19<00:00,  1.09it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [16:20<00:00, 980.39s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/980 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/980 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/980 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/1021 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/1021 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 1021 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/980 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\postprocessing\template_similarity.py:345: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   overlapping_ids = overlapping_j_list[i]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/980 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8251_recall_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8251_recall_g0
# 🧹 Memory cleared for H:\Data\raw\8251_recall_g0
#
# === Processing H:\Data\raw\8182_naive_g2 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 141,791,867 samples
#                             4,726.41s (1.31 hours) - int16 dtype - 101.42 GiB
# Bad channels: ['imec0.ap#AP1' 'imec0.ap#AP3' 'imec0.ap#AP191' 'imec0.ap#AP348'
#  'imec0.ap#AP349' 'imec0.ap#AP350' 'imec0.ap#AP351' 'imec0.ap#AP352'
#  'imec0.ap#AP353' 'imec0.ap#AP354' 'imec0.ap#AP355' 'imec0.ap#AP356'
#  'imec0.ap#AP357' 'imec0.ap#AP358' 'imec0.ap#AP359' 'imec0.ap#AP360'
#  'imec0.ap#AP361' 'imec0.ap#AP362' 'imec0.ap#AP363' 'imec0.ap#AP364'
#  'imec0.ap#AP365' 'imec0.ap#AP366' 'imec0.ap#AP367' 'imec0.ap#AP368'
#  'imec0.ap#AP369' 'imec0.ap#AP370' 'imec0.ap#AP371' 'imec0.ap#AP372'
#  'imec0.ap#AP373' 'imec0.ap#AP374' 'imec0.ap#AP375' 'imec0.ap#AP376'
#  'imec0.ap#AP377' 'imec0.ap#AP378' 'imec0.ap#AP379' 'imec0.ap#AP380'
#  'imec0.ap#AP381' 'imec0.ap#AP382' 'imec0.ap#AP383']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2364/2364 [29:10<00:00,  1.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2364/2364 [26:42<00:00,  1.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [01:54<00:00, 114.88s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2364/2364 [07:49<00:00,  5.04it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:50<00:00, 170.42s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/946 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/946 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/946 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/246 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/246 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 246 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/946 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/946 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8182_naive_g2\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8182_naive_g2
# 🧹 Memory cleared for H:\Data\raw\8182_naive_g2
#
# === Processing H:\Data\raw\8181_naivel_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 146,115,560 samples
#                             4,870.53s (1.35 hours) - int16 dtype - 104.51 GiB
# Bad channels: ['imec0.ap#AP191']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2436/2436 [30:18<00:00,  1.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2436/2436 [30:12<00:00,  1.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:12<00:00, 132.45s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2436/2436 [12:22<00:00,  3.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [03:13<00:00, 193.48s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/975 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/975 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/975 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/335 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/335 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 335 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/975 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/975 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8181_naivel_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8181_naivel_g0
# 🧹 Memory cleared for H:\Data\raw\8181_naivel_g0
#
# === Processing H:\Data\raw\8252_recall_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 144,343,486 samples
#                             4,811.47s (1.34 hours) - int16 dtype - 103.24 GiB
# Bad channels: ['imec0.ap#AP191']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2406/2406 [30:38<00:00,  1.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2406/2406 [29:58<00:00,  1.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:07<00:00, 127.41s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2406/2406 [12:42<00:00,  3.15it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [03:24<00:00, 204.86s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/329 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/329 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 329 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8252_recall_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8252_recall_g0
# 🧹 Memory cleared for H:\Data\raw\8252_recall_g0
#
# === Processing H:\Data\raw\8252_naive_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 146,486,901 samples
#                             4,882.91s (1.36 hours) - int16 dtype - 104.78 GiB
# Bad channels: ['imec0.ap#AP2' 'imec0.ap#AP5' 'imec0.ap#AP8' 'imec0.ap#AP26'
#  'imec0.ap#AP33' 'imec0.ap#AP65' 'imec0.ap#AP66' 'imec0.ap#AP68'
#  'imec0.ap#AP73' 'imec0.ap#AP76' 'imec0.ap#AP79' 'imec0.ap#AP82'
#  'imec0.ap#AP97' 'imec0.ap#AP99' 'imec0.ap#AP105' 'imec0.ap#AP112'
#  'imec0.ap#AP125' 'imec0.ap#AP147' 'imec0.ap#AP150' 'imec0.ap#AP152'
#  'imec0.ap#AP162' 'imec0.ap#AP177' 'imec0.ap#AP179' 'imec0.ap#AP183'
#  'imec0.ap#AP186' 'imec0.ap#AP189' 'imec0.ap#AP194' 'imec0.ap#AP196'
#  'imec0.ap#AP199' 'imec0.ap#AP200' 'imec0.ap#AP201' 'imec0.ap#AP205'
#  'imec0.ap#AP209' 'imec0.ap#AP211' 'imec0.ap#AP213' 'imec0.ap#AP215'
#  'imec0.ap#AP221' 'imec0.ap#AP226' 'imec0.ap#AP230' 'imec0.ap#AP231'
#  'imec0.ap#AP232' 'imec0.ap#AP238' 'imec0.ap#AP241' 'imec0.ap#AP242'
#  'imec0.ap#AP244' 'imec0.ap#AP250' 'imec0.ap#AP252' 'imec0.ap#AP253'
#  'imec0.ap#AP258' 'imec0.ap#AP263' 'imec0.ap#AP265' 'imec0.ap#AP266'
#  'imec0.ap#AP273' 'imec0.ap#AP276' 'imec0.ap#AP279' 'imec0.ap#AP281'
#  'imec0.ap#AP285' 'imec0.ap#AP286' 'imec0.ap#AP301' 'imec0.ap#AP307'
#  'imec0.ap#AP312' 'imec0.ap#AP314' 'imec0.ap#AP316' 'imec0.ap#AP318'
#  'imec0.ap#AP322' 'imec0.ap#AP323' 'imec0.ap#AP324' 'imec0.ap#AP339'
#  'imec0.ap#AP346' 'imec0.ap#AP347' 'imec0.ap#AP354' 'imec0.ap#AP356'
#  'imec0.ap#AP357' 'imec0.ap#AP363' 'imec0.ap#AP372' 'imec0.ap#AP378'
#  'imec0.ap#AP381']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2442/2442 [30:26<00:00,  1.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2442/2442 [30:32<00:00,  1.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [04:13<00:00, 253.78s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2442/2442 [14:26<00:00,  2.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [06:00<00:00, 360.45s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/977 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/977 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/977 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/323 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/323 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 323 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/977 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/977 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8252_naive_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8252_naive_g0
# 🧹 Memory cleared for H:\Data\raw\8252_naive_g0
#
# === Processing H:\Data\raw\8251_naive_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 147,977,096 samples
#                             4,932.59s (1.37 hours) - int16 dtype - 105.84 GiB
# Bad channels: ['imec0.ap#AP1' 'imec0.ap#AP3' 'imec0.ap#AP53' 'imec0.ap#AP97'
#  'imec0.ap#AP191']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2467/2467 [30:43<00:00,  1.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2467/2467 [32:29<00:00,  1.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [10:49<00:00, 649.92s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2467/2467 [38:15<00:00,  1.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 1/1 [25:49<00:00, 1549.87s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/987 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/987 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# ❌ Error processing H:\Data\raw\8251_naive_g0: [Errno 22] Invalid argument
# 🧹 Memory cleared for H:\Data\raw\8251_naive_g0
#
# === Processing H:\Data\raw\8273_recall_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 144,338,040 samples
#                             4,811.28s (1.34 hours) - int16 dtype - 103.24 GiB
# Bad channels: ['imec0.ap#AP191']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2406/2406 [29:37<00:00,  1.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2406/2406 [30:22<00:00,  1.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:21<00:00, 141.37s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2406/2406 [11:58<00:00,  3.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [03:30<00:00, 210.58s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/332 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/332 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 332 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/963 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8273_recall_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8273_recall_g0
# 🧹 Memory cleared for H:\Data\raw\8273_recall_g0
#
# === Processing H:\Data\raw\8272_recall_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 144,700,192 samples
#                             4,823.36s (1.34 hours) - int16 dtype - 103.50 GiB
# Bad channels: ['imec0.ap#AP191' 'imec0.ap#AP343' 'imec0.ap#AP344' 'imec0.ap#AP345'
#  'imec0.ap#AP346' 'imec0.ap#AP347' 'imec0.ap#AP348' 'imec0.ap#AP349'
#  'imec0.ap#AP350' 'imec0.ap#AP351' 'imec0.ap#AP352' 'imec0.ap#AP353'
#  'imec0.ap#AP354' 'imec0.ap#AP355' 'imec0.ap#AP356' 'imec0.ap#AP357'
#  'imec0.ap#AP358' 'imec0.ap#AP359' 'imec0.ap#AP360' 'imec0.ap#AP361'
#  'imec0.ap#AP362' 'imec0.ap#AP363' 'imec0.ap#AP364' 'imec0.ap#AP365'
#  'imec0.ap#AP366' 'imec0.ap#AP367' 'imec0.ap#AP368' 'imec0.ap#AP369'
#  'imec0.ap#AP370' 'imec0.ap#AP371' 'imec0.ap#AP372' 'imec0.ap#AP373'
#  'imec0.ap#AP374' 'imec0.ap#AP375' 'imec0.ap#AP376' 'imec0.ap#AP377'
#  'imec0.ap#AP378' 'imec0.ap#AP379' 'imec0.ap#AP380' 'imec0.ap#AP381'
#  'imec0.ap#AP382' 'imec0.ap#AP383']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2412/2412 [29:56<00:00,  1.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2412/2412 [30:09<00:00,  1.33it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [03:31<00:00, 211.44s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2412/2412 [14:29<00:00,  2.77it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [06:32<00:00, 392.78s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/965 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/965 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/965 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/339 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/339 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 339 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/965 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/965 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8272_recall_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8272_recall_g0
# 🧹 Memory cleared for H:\Data\raw\8272_recall_g0
#
# === Processing H:\Data\raw\8273_naive_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 143,240,695 samples
#                             4,774.71s (1.33 hours) - int16 dtype - 102.45 GiB
# Bad channels: ['imec0.ap#AP1' 'imec0.ap#AP191' 'imec0.ap#AP339' 'imec0.ap#AP340'
#  'imec0.ap#AP341' 'imec0.ap#AP342' 'imec0.ap#AP343' 'imec0.ap#AP344'
#  'imec0.ap#AP345' 'imec0.ap#AP346' 'imec0.ap#AP347' 'imec0.ap#AP348'
#  'imec0.ap#AP349' 'imec0.ap#AP350' 'imec0.ap#AP351' 'imec0.ap#AP352'
#  'imec0.ap#AP353' 'imec0.ap#AP354' 'imec0.ap#AP355' 'imec0.ap#AP356'
#  'imec0.ap#AP357' 'imec0.ap#AP358' 'imec0.ap#AP359' 'imec0.ap#AP360'
#  'imec0.ap#AP361' 'imec0.ap#AP362' 'imec0.ap#AP363' 'imec0.ap#AP364'
#  'imec0.ap#AP365' 'imec0.ap#AP366' 'imec0.ap#AP367' 'imec0.ap#AP368'
#  'imec0.ap#AP369' 'imec0.ap#AP370' 'imec0.ap#AP371' 'imec0.ap#AP372'
#  'imec0.ap#AP373' 'imec0.ap#AP374' 'imec0.ap#AP375' 'imec0.ap#AP376'
#  'imec0.ap#AP377' 'imec0.ap#AP378' 'imec0.ap#AP379' 'imec0.ap#AP380'
#  'imec0.ap#AP381' 'imec0.ap#AP382' 'imec0.ap#AP383']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2388/2388 [29:41<00:00,  1.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2388/2388 [29:31<00:00,  1.35it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:40<00:00, 160.64s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2388/2388 [14:59<00:00,  2.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [04:37<00:00, 277.49s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/955 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/955 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/955 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/484 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/484 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 484 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/955 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/955 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8273_naive_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8273_naive_g0
# 🧹 Memory cleared for H:\Data\raw\8273_naive_g0
#
# === Processing H:\Data\raw\8272_g1 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 141,747,463 samples
#                             4,724.93s (1.31 hours) - int16 dtype - 101.39 GiB
# Bad channels: ['imec0.ap#AP191']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2363/2363 [29:17<00:00,  1.34it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2363/2363 [28:35<00:00,  1.38it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [03:51<00:00, 231.03s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2363/2363 [17:26<00:00,  2.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [07:07<00:00, 427.28s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/945 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/945 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/945 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/460 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/460 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 460 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/945 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/945 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8272_g1\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8272_g1
# 🧹 Memory cleared for H:\Data\raw\8272_g1
#
# === Processing H:\Data\raw\8181_recall_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 142,587,812 samples
#                             4,752.94s (1.32 hours) - int16 dtype - 101.99 GiB
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\preprocessing\detect_bad_channels.py:300: UserWarning: Over 1/3 of channels are detected as bad. In the presence of a highnumber of dead / noisy channels, bad channel detection may fail (good channels may be erroneously labeled as dead).
#   warnings.warn(
# Bad channels: ['imec0.ap#AP1' 'imec0.ap#AP3' 'imec0.ap#AP5' 'imec0.ap#AP6'
#  'imec0.ap#AP7' 'imec0.ap#AP8' 'imec0.ap#AP9' 'imec0.ap#AP10'
#  'imec0.ap#AP11' 'imec0.ap#AP12' 'imec0.ap#AP13' 'imec0.ap#AP14'
#  'imec0.ap#AP15' 'imec0.ap#AP16' 'imec0.ap#AP17' 'imec0.ap#AP18'
#  'imec0.ap#AP19' 'imec0.ap#AP20' 'imec0.ap#AP21' 'imec0.ap#AP22'
#  'imec0.ap#AP23' 'imec0.ap#AP24' 'imec0.ap#AP25' 'imec0.ap#AP26'
#  'imec0.ap#AP27' 'imec0.ap#AP28' 'imec0.ap#AP29' 'imec0.ap#AP30'
#  'imec0.ap#AP31' 'imec0.ap#AP32' 'imec0.ap#AP33' 'imec0.ap#AP34'
#  'imec0.ap#AP35' 'imec0.ap#AP36' 'imec0.ap#AP37' 'imec0.ap#AP38'
#  'imec0.ap#AP39' 'imec0.ap#AP40' 'imec0.ap#AP41' 'imec0.ap#AP42'
#  'imec0.ap#AP43' 'imec0.ap#AP44' 'imec0.ap#AP45' 'imec0.ap#AP46'
#  'imec0.ap#AP47' 'imec0.ap#AP48' 'imec0.ap#AP49' 'imec0.ap#AP50'
#  'imec0.ap#AP51' 'imec0.ap#AP52' 'imec0.ap#AP53' 'imec0.ap#AP54'
#  'imec0.ap#AP55' 'imec0.ap#AP56' 'imec0.ap#AP57' 'imec0.ap#AP58'
#  'imec0.ap#AP59' 'imec0.ap#AP60' 'imec0.ap#AP61' 'imec0.ap#AP62'
#  'imec0.ap#AP63' 'imec0.ap#AP64' 'imec0.ap#AP65' 'imec0.ap#AP66'
#  'imec0.ap#AP67' 'imec0.ap#AP68' 'imec0.ap#AP69' 'imec0.ap#AP70'
#  'imec0.ap#AP72' 'imec0.ap#AP73' 'imec0.ap#AP74' 'imec0.ap#AP78'
#  'imec0.ap#AP80' 'imec0.ap#AP82' 'imec0.ap#AP83' 'imec0.ap#AP84'
#  'imec0.ap#AP85' 'imec0.ap#AP86' 'imec0.ap#AP87' 'imec0.ap#AP88'
#  'imec0.ap#AP89' 'imec0.ap#AP90' 'imec0.ap#AP91' 'imec0.ap#AP92'
#  'imec0.ap#AP93' 'imec0.ap#AP94' 'imec0.ap#AP95' 'imec0.ap#AP96'
#  'imec0.ap#AP97' 'imec0.ap#AP98' 'imec0.ap#AP99' 'imec0.ap#AP100'
#  'imec0.ap#AP101' 'imec0.ap#AP102' 'imec0.ap#AP103' 'imec0.ap#AP104'
#  'imec0.ap#AP105' 'imec0.ap#AP106' 'imec0.ap#AP107' 'imec0.ap#AP108'
#  'imec0.ap#AP109' 'imec0.ap#AP110' 'imec0.ap#AP111' 'imec0.ap#AP112'
#  'imec0.ap#AP114' 'imec0.ap#AP116' 'imec0.ap#AP120' 'imec0.ap#AP122'
#  'imec0.ap#AP124' 'imec0.ap#AP125' 'imec0.ap#AP126' 'imec0.ap#AP127'
#  'imec0.ap#AP128' 'imec0.ap#AP129' 'imec0.ap#AP130' 'imec0.ap#AP131'
#  'imec0.ap#AP132' 'imec0.ap#AP133' 'imec0.ap#AP134' 'imec0.ap#AP135'
#  'imec0.ap#AP136' 'imec0.ap#AP137' 'imec0.ap#AP138' 'imec0.ap#AP139'
#  'imec0.ap#AP140' 'imec0.ap#AP141' 'imec0.ap#AP142' 'imec0.ap#AP143'
#  'imec0.ap#AP144' 'imec0.ap#AP145' 'imec0.ap#AP146' 'imec0.ap#AP147'
#  'imec0.ap#AP148' 'imec0.ap#AP149' 'imec0.ap#AP150' 'imec0.ap#AP151'
#  'imec0.ap#AP152' 'imec0.ap#AP153' 'imec0.ap#AP154' 'imec0.ap#AP155'
#  'imec0.ap#AP156' 'imec0.ap#AP158' 'imec0.ap#AP160' 'imec0.ap#AP164'
#  'imec0.ap#AP165' 'imec0.ap#AP166' 'imec0.ap#AP168' 'imec0.ap#AP169'
#  'imec0.ap#AP170' 'imec0.ap#AP171' 'imec0.ap#AP172' 'imec0.ap#AP173'
#  'imec0.ap#AP174' 'imec0.ap#AP175' 'imec0.ap#AP176' 'imec0.ap#AP177'
#  'imec0.ap#AP178' 'imec0.ap#AP179' 'imec0.ap#AP180' 'imec0.ap#AP181'
#  'imec0.ap#AP182' 'imec0.ap#AP183' 'imec0.ap#AP184' 'imec0.ap#AP185'
#  'imec0.ap#AP186' 'imec0.ap#AP187' 'imec0.ap#AP188' 'imec0.ap#AP189'
#  'imec0.ap#AP190' 'imec0.ap#AP191' 'imec0.ap#AP192' 'imec0.ap#AP193'
#  'imec0.ap#AP194' 'imec0.ap#AP195' 'imec0.ap#AP196' 'imec0.ap#AP197'
#  'imec0.ap#AP198' 'imec0.ap#AP199' 'imec0.ap#AP200' 'imec0.ap#AP201'
#  'imec0.ap#AP202' 'imec0.ap#AP203' 'imec0.ap#AP204' 'imec0.ap#AP205'
#  'imec0.ap#AP206' 'imec0.ap#AP207' 'imec0.ap#AP208' 'imec0.ap#AP209'
#  'imec0.ap#AP210' 'imec0.ap#AP211' 'imec0.ap#AP212' 'imec0.ap#AP213'
#  'imec0.ap#AP214' 'imec0.ap#AP215' 'imec0.ap#AP216' 'imec0.ap#AP217'
#  'imec0.ap#AP218' 'imec0.ap#AP219' 'imec0.ap#AP220' 'imec0.ap#AP221'
#  'imec0.ap#AP222' 'imec0.ap#AP223' 'imec0.ap#AP224' 'imec0.ap#AP225'
#  'imec0.ap#AP226' 'imec0.ap#AP227' 'imec0.ap#AP228' 'imec0.ap#AP229'
#  'imec0.ap#AP230' 'imec0.ap#AP231' 'imec0.ap#AP232' 'imec0.ap#AP233'
#  'imec0.ap#AP234' 'imec0.ap#AP235' 'imec0.ap#AP236' 'imec0.ap#AP237'
#  'imec0.ap#AP238' 'imec0.ap#AP239' 'imec0.ap#AP240' 'imec0.ap#AP241'
#  'imec0.ap#AP242' 'imec0.ap#AP243' 'imec0.ap#AP244' 'imec0.ap#AP245'
#  'imec0.ap#AP246' 'imec0.ap#AP247' 'imec0.ap#AP248' 'imec0.ap#AP249'
#  'imec0.ap#AP250' 'imec0.ap#AP251' 'imec0.ap#AP252' 'imec0.ap#AP253'
#  'imec0.ap#AP254' 'imec0.ap#AP255' 'imec0.ap#AP256' 'imec0.ap#AP257'
#  'imec0.ap#AP258' 'imec0.ap#AP259' 'imec0.ap#AP260' 'imec0.ap#AP261'
#  'imec0.ap#AP262' 'imec0.ap#AP263' 'imec0.ap#AP264' 'imec0.ap#AP265'
#  'imec0.ap#AP266' 'imec0.ap#AP267' 'imec0.ap#AP268' 'imec0.ap#AP269'
#  'imec0.ap#AP270' 'imec0.ap#AP271' 'imec0.ap#AP272' 'imec0.ap#AP273'
#  'imec0.ap#AP274' 'imec0.ap#AP275' 'imec0.ap#AP276' 'imec0.ap#AP277'
#  'imec0.ap#AP278' 'imec0.ap#AP279' 'imec0.ap#AP280' 'imec0.ap#AP281'
#  'imec0.ap#AP282' 'imec0.ap#AP283' 'imec0.ap#AP284' 'imec0.ap#AP285'
#  'imec0.ap#AP286' 'imec0.ap#AP287' 'imec0.ap#AP288' 'imec0.ap#AP289'
#  'imec0.ap#AP290' 'imec0.ap#AP291' 'imec0.ap#AP292' 'imec0.ap#AP293'
#  'imec0.ap#AP294' 'imec0.ap#AP295' 'imec0.ap#AP296' 'imec0.ap#AP297'
#  'imec0.ap#AP298' 'imec0.ap#AP299' 'imec0.ap#AP300' 'imec0.ap#AP301'
#  'imec0.ap#AP302' 'imec0.ap#AP303' 'imec0.ap#AP304' 'imec0.ap#AP305'
#  'imec0.ap#AP306' 'imec0.ap#AP307' 'imec0.ap#AP308' 'imec0.ap#AP309'
#  'imec0.ap#AP310' 'imec0.ap#AP311' 'imec0.ap#AP312' 'imec0.ap#AP313'
#  'imec0.ap#AP314' 'imec0.ap#AP315' 'imec0.ap#AP316' 'imec0.ap#AP317'
#  'imec0.ap#AP318' 'imec0.ap#AP319' 'imec0.ap#AP320' 'imec0.ap#AP321'
#  'imec0.ap#AP322' 'imec0.ap#AP323' 'imec0.ap#AP324' 'imec0.ap#AP325'
#  'imec0.ap#AP326' 'imec0.ap#AP327' 'imec0.ap#AP328' 'imec0.ap#AP329'
#  'imec0.ap#AP330' 'imec0.ap#AP331' 'imec0.ap#AP332' 'imec0.ap#AP333'
#  'imec0.ap#AP334' 'imec0.ap#AP335' 'imec0.ap#AP336' 'imec0.ap#AP337'
#  'imec0.ap#AP338' 'imec0.ap#AP339' 'imec0.ap#AP340' 'imec0.ap#AP341'
#  'imec0.ap#AP342' 'imec0.ap#AP343' 'imec0.ap#AP344' 'imec0.ap#AP345'
#  'imec0.ap#AP346' 'imec0.ap#AP347' 'imec0.ap#AP348' 'imec0.ap#AP349'
#  'imec0.ap#AP350' 'imec0.ap#AP351' 'imec0.ap#AP352' 'imec0.ap#AP353'
#  'imec0.ap#AP354' 'imec0.ap#AP355' 'imec0.ap#AP356' 'imec0.ap#AP357'
#  'imec0.ap#AP358' 'imec0.ap#AP359' 'imec0.ap#AP360' 'imec0.ap#AP361'
#  'imec0.ap#AP362' 'imec0.ap#AP363' 'imec0.ap#AP364' 'imec0.ap#AP365'
#  'imec0.ap#AP366' 'imec0.ap#AP367' 'imec0.ap#AP368' 'imec0.ap#AP369'
#  'imec0.ap#AP370' 'imec0.ap#AP371' 'imec0.ap#AP372' 'imec0.ap#AP373'
#  'imec0.ap#AP374' 'imec0.ap#AP375' 'imec0.ap#AP376' 'imec0.ap#AP377'
#  'imec0.ap#AP378' 'imec0.ap#AP379' 'imec0.ap#AP380' 'imec0.ap#AP381'
#  'imec0.ap#AP382' 'imec0.ap#AP383']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2377/2377 [29:10<00:00,  1.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2377/2377 [26:48<00:00,  1.48it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.44s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2377/2377 [06:54<00:00,  5.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:17<00:00, 17.16s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/951 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/951 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/951 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/94 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/94 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 94 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/951 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/951 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8181_recall_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8181_recall_g0
# 🧹 Memory cleared for H:\Data\raw\8181_recall_g0
#
# === Processing H:\Data\raw\8182_recall_g0 ===
# SpikeGLXRecordingExtractor: 384 channels - 29999.900000 Hz - 1 segments - 145,656,071 samples
#                             4,855.22s (1.35 hours) - int16 dtype - 104.18 GiB
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\preprocessing\detect_bad_channels.py:300: UserWarning: Over 1/3 of channels are detected as bad. In the presence of a highnumber of dead / noisy channels, bad channel detection may fail (good channels may be erroneously labeled as dead).
#   warnings.warn(
# Bad channels: ['imec0.ap#AP0' 'imec0.ap#AP6' 'imec0.ap#AP11' 'imec0.ap#AP12'
#  'imec0.ap#AP13' 'imec0.ap#AP15' 'imec0.ap#AP16' 'imec0.ap#AP17'
#  'imec0.ap#AP18' 'imec0.ap#AP19' 'imec0.ap#AP20' 'imec0.ap#AP23'
#  'imec0.ap#AP24' 'imec0.ap#AP25' 'imec0.ap#AP31' 'imec0.ap#AP36'
#  'imec0.ap#AP40' 'imec0.ap#AP41' 'imec0.ap#AP42' 'imec0.ap#AP43'
#  'imec0.ap#AP46' 'imec0.ap#AP47' 'imec0.ap#AP48' 'imec0.ap#AP57'
#  'imec0.ap#AP59' 'imec0.ap#AP64' 'imec0.ap#AP72' 'imec0.ap#AP77'
#  'imec0.ap#AP78' 'imec0.ap#AP82' 'imec0.ap#AP83' 'imec0.ap#AP87'
#  'imec0.ap#AP88' 'imec0.ap#AP90' 'imec0.ap#AP91' 'imec0.ap#AP92'
#  'imec0.ap#AP95' 'imec0.ap#AP96' 'imec0.ap#AP97' 'imec0.ap#AP98'
#  'imec0.ap#AP99' 'imec0.ap#AP104' 'imec0.ap#AP105' 'imec0.ap#AP107'
#  'imec0.ap#AP108' 'imec0.ap#AP113' 'imec0.ap#AP114' 'imec0.ap#AP121'
#  'imec0.ap#AP125' 'imec0.ap#AP126' 'imec0.ap#AP128' 'imec0.ap#AP130'
#  'imec0.ap#AP131' 'imec0.ap#AP134' 'imec0.ap#AP135' 'imec0.ap#AP139'
#  'imec0.ap#AP141' 'imec0.ap#AP142' 'imec0.ap#AP145' 'imec0.ap#AP147'
#  'imec0.ap#AP150' 'imec0.ap#AP152' 'imec0.ap#AP154' 'imec0.ap#AP156'
#  'imec0.ap#AP157' 'imec0.ap#AP158' 'imec0.ap#AP159' 'imec0.ap#AP160'
#  'imec0.ap#AP163' 'imec0.ap#AP164' 'imec0.ap#AP165' 'imec0.ap#AP167'
#  'imec0.ap#AP173' 'imec0.ap#AP176' 'imec0.ap#AP177' 'imec0.ap#AP178'
#  'imec0.ap#AP179' 'imec0.ap#AP180' 'imec0.ap#AP181' 'imec0.ap#AP184'
#  'imec0.ap#AP185' 'imec0.ap#AP189' 'imec0.ap#AP191' 'imec0.ap#AP192'
#  'imec0.ap#AP195' 'imec0.ap#AP197' 'imec0.ap#AP198' 'imec0.ap#AP201'
#  'imec0.ap#AP203' 'imec0.ap#AP204' 'imec0.ap#AP205' 'imec0.ap#AP209'
#  'imec0.ap#AP211' 'imec0.ap#AP213' 'imec0.ap#AP215' 'imec0.ap#AP218'
#  'imec0.ap#AP220' 'imec0.ap#AP221' 'imec0.ap#AP222' 'imec0.ap#AP223'
#  'imec0.ap#AP226' 'imec0.ap#AP228' 'imec0.ap#AP230' 'imec0.ap#AP231'
#  'imec0.ap#AP232' 'imec0.ap#AP233' 'imec0.ap#AP237' 'imec0.ap#AP242'
#  'imec0.ap#AP244' 'imec0.ap#AP250' 'imec0.ap#AP252' 'imec0.ap#AP253'
#  'imec0.ap#AP258' 'imec0.ap#AP260' 'imec0.ap#AP262' 'imec0.ap#AP263'
#  'imec0.ap#AP266' 'imec0.ap#AP273' 'imec0.ap#AP277' 'imec0.ap#AP281'
#  'imec0.ap#AP282' 'imec0.ap#AP287' 'imec0.ap#AP288' 'imec0.ap#AP289'
#  'imec0.ap#AP290' 'imec0.ap#AP291' 'imec0.ap#AP292' 'imec0.ap#AP294'
#  'imec0.ap#AP295' 'imec0.ap#AP297' 'imec0.ap#AP300' 'imec0.ap#AP303'
#  'imec0.ap#AP306' 'imec0.ap#AP307' 'imec0.ap#AP312' 'imec0.ap#AP314'
#  'imec0.ap#AP315' 'imec0.ap#AP316' 'imec0.ap#AP338' 'imec0.ap#AP362'
#  'imec0.ap#AP363' 'imec0.ap#AP364' 'imec0.ap#AP365' 'imec0.ap#AP366'
#  'imec0.ap#AP367' 'imec0.ap#AP368' 'imec0.ap#AP369' 'imec0.ap#AP370'
#  'imec0.ap#AP371' 'imec0.ap#AP372' 'imec0.ap#AP373' 'imec0.ap#AP374'
#  'imec0.ap#AP375' 'imec0.ap#AP376' 'imec0.ap#AP377' 'imec0.ap#AP378'
#  'imec0.ap#AP379' 'imec0.ap#AP380' 'imec0.ap#AP381' 'imec0.ap#AP382'
#  'imec0.ap#AP383']
# 100%|██████████████████████████████████████████████████████████████████████████████| 2428/2428 [29:58<00:00,  1.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2428/2428 [30:10<00:00,  1.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [02:33<00:00, 153.87s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2428/2428 [13:25<00:00,  3.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [03:59<00:00, 239.13s/it]
# estimate_sparsity (workers: 39 processes spawn):   0%|          | 0/972 [00:00<?, ?it/s]
# C:\Users\Freitag\si_env\Lib\site-packages\spikeinterface\core\basesorting.py:384: UserWarning: The registered recording will not be persistent on disk, but only available in memory
#   warnings.warn("The registered recording will not be persistent on disk, but only available in memory")
# compute_waveforms (workers: 39 processes spawn):   0%|          | 0/972 [00:00<?, ?it/s]
# noise_level (workers: 20 processes spawn):   0%|          | 0/20 [00:00<?, ?it/s]
# spike_amplitudes (workers: 39 processes spawn):   0%|          | 0/972 [00:00<?, ?it/s]
# Fitting PCA:   0%|          | 0/310 [00:00<?, ?it/s]
# Projecting waveforms:   0%|          | 0/310 [00:00<?, ?it/s]
# SortingAnalyzer: 384 channels - 310 units - 1 segments - binary_folder - sparse - has recording
# Loaded 8 extensions: random_spikes, waveforms, templates, noise_levels, unit_locations, correlograms, spike_amplitudes, principal_components
# write_binary_recording (workers: 39 processes spawn):   0%|          | 0/972 [00:00<?, ?it/s]
# extract PCs (workers: 39 processes spawn):   0%|          | 0/972 [00:00<?, ?it/s]
# Run:
# phy template-gui  H:\Data\raw\8182_recall_g0\sorted\phy\params.py
# ✅ Finished H:\Data\raw\8182_recall_g0
# 🧹 Memory cleared for H:\Data\raw\8182_recall_g0

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.current_device())
torch.cuda.get_device_name(0)
# Out:
# True
# 0
# 'NVIDIA RTX A4000'
